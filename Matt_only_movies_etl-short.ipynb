# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
# import the imdb data
imdb_file = "IMDb movies.csv"
imdb_df = pd.read_csv(imdb_file)
imdb_df.head()
# Out:
#   imdb_title_id                                              title  \
# 0     tt0000574                        The Story of the Kelly Gang
# 1     tt0001892                                     Den sorte drøm
# 2     tt0002101                                          Cleopatra
# 3     tt0002130                                          L'Inferno
# 4     tt0002199  From the Manger to the Cross; or, Jesus of Naz...
#
#                                       original_title  year date_published  \
# 0                        The Story of the Kelly Gang  1906     1906-12-26
# 1                                     Den sorte drøm  1911     1911-08-19
# 2                                          Cleopatra  1912     1912-11-13
# 3                                          L'Inferno  1911     1911-03-06
# 4  From the Manger to the Cross; or, Jesus of Naz...  1912           1913
#
#                        genre  duration           country language  \
# 0    Biography, Crime, Drama        70         Australia      NaN
# 1                      Drama        53  Germany, Denmark      NaN
# 2             Drama, History       100               USA  English
# 3  Adventure, Drama, Fantasy        68             Italy  Italian
# 4           Biography, Drama        60               USA  English
#
#                               director  ...  \
# 0                         Charles Tait  ...
# 1                            Urban Gad  ...
# 2                   Charles L. Gaskill  ...
# 3  Francesco Bertolini, Adolfo Padovan  ...
# 4                        Sidney Olcott  ...
#
#                                               actors  \
# 0  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 1  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 2  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 3  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
# 4  R. Henderson Bland, Percy Dyer, Gene Gauntier,...
#
#                                          description avg_vote votes   budget  \
# 0  True story of notorious Australian outlaw Ned ...      6.1   537   $ 2250
# 1  Two men of high rank are both wooing the beaut...      5.9   171      NaN
# 2  The fabled queen of Egypt's affair with Roman ...      5.2   420  $ 45000
# 3  Loosely adapted from Dante's Divine Comedy and...      7.0  2019      NaN
# 4  An account of the life of Jesus Christ, based ...      5.7   438      NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                7.0
# 1               NaN                   NaN       NaN                4.0
# 2               NaN                   NaN       NaN               24.0
# 3               NaN                   NaN       NaN               28.0
# 4               NaN                   NaN       NaN               12.0
#
#    reviews_from_critics
# 0                   7.0
# 1                   2.0
# 2                   3.0
# 3                  14.0
# 4                   5.0
#
# [5 rows x 22 columns]

# %%
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81273 entries, 0 to 81272
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          81273 non-null  object
#  1   title                  81273 non-null  object
#  2   original_title         81273 non-null  object
#  3   year                   81273 non-null  int64
#  4   date_published         81273 non-null  object
#  5   genre                  81273 non-null  object
#  6   duration               81273 non-null  int64
#  7   country                81234 non-null  object
#  8   language               80518 non-null  object
#  9   director               81200 non-null  object
#  10  writer                 79780 non-null  object
#  11  production_company     76948 non-null  object
#  12  actors                 81207 non-null  object
#  13  description            78843 non-null  object
#  14  avg_vote               81273 non-null  float64
#  15  votes                  81273 non-null  int64
#  16  budget                 22804 non-null  object
#  17  usa_gross_income       15094 non-null  object
#  18  worlwide_gross_income  29892 non-null  object
#  19  metascore              12722 non-null  float64
#  20  reviews_from_users     74196 non-null  float64
#  21  reviews_from_critics   70286 non-null  float64
# dtypes: float64(4), int64(3), object(15)
# memory usage: 13.6+ MB

# %%
# import the netflix data
netflix_file = "netflix_titles.csv"
netflix_df = pd.read_csv(netflix_file)
netflix_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6234 entries, 0 to 6233
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6234 non-null   int64
#  1   type          6234 non-null   object
#  2   title         6234 non-null   object
#  3   director      4265 non-null   object
#  4   cast          5664 non-null   object
#  5   country       5758 non-null   object
#  6   date_added    6223 non-null   object
#  7   release_year  6234 non-null   int64
#  8   rating        6224 non-null   object
#  9   duration      6234 non-null   object
#  10  listed_in     6234 non-null   object
#  11  description   6234 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 584.6+ KB

# %%
#split the netflix data intp movies and TV shows
netflix_movies_df = netflix_df.loc[netflix_df['type']=='Movie',:]
netflix_movies_df.info()
netflix_TV_df = netflix_df.loc[netflix_df['type']=='TV Show']
netflix_TV_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4265 entries, 0 to 6231
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       4265 non-null   int64
#  1   type          4265 non-null   object
#  2   title         4265 non-null   object
#  3   director      4137 non-null   object
#  4   cast          3905 non-null   object
#  5   country       4070 non-null   object
#  6   date_added    4264 non-null   object
#  7   release_year  4265 non-null   int64
#  8   rating        4257 non-null   object
#  9   duration      4265 non-null   object
#  10  listed_in     4265 non-null   object
#  11  description   4265 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 433.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1969 entries, 2 to 6233
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       1969 non-null   int64
#  1   type          1969 non-null   object
#  2   title         1969 non-null   object
#  3   director      128 non-null    object
#  4   cast          1759 non-null   object
#  5   country       1688 non-null   object
#  6   date_added    1959 non-null   object
#  7   release_year  1969 non-null   int64
#  8   rating        1967 non-null   object
#  9   duration      1969 non-null   object
#  10  listed_in     1969 non-null   object
#  11  description   1969 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 200.0+ KB

# %%
# after checking the data we decided to merge on directors + title
# to avoid mismatches in the data
#check for missing directors in the data
bool_series = pd.isnull(netflix_movies_df["director"])  
print (f"There are {len(netflix_movies_df[bool_series])} movies with no director information") 
bool_series = pd.isnull(netflix_TV_df["director"])  
print (f"There are {len(netflix_TV_df[bool_series])} TV Shows with no director information")
# Out:
# There are 128 movies with no director information
# There are 1841 TV Shows with no director information

# %%
#There are very few tv shows with matching data
combined_TV_df = pd.merge(netflix_TV_df, imdb_df, left_on=['title'], 
                    right_on=['title'], suffixes=('_net', '_imdb') )

print (f" There are {len(combined_TV_df)} matching TV shows that have director data")
# Out:
#  There are 409 matching TV shows that have director data

# %%
# merge the two data sets on title and director
combined_movie_df = pd.merge(netflix_movies_df, imdb_df, left_on=['title','director'], 
                    right_on=['title','director'], suffixes=('_net', '_imdb') )
combined_movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1800 entries, 0 to 1799
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   show_id                1800 non-null   int64
#  1   type                   1800 non-null   object
#  2   title                  1800 non-null   object
#  3   director               1800 non-null   object
#  4   cast                   1798 non-null   object
#  5   country_net            1796 non-null   object
#  6   date_added             1800 non-null   object
#  7   release_year           1800 non-null   int64
#  8   rating                 1799 non-null   object
#  9   duration_net           1800 non-null   object
#  10  listed_in              1800 non-null   object
#  11  description_net        1800 non-null   object
#  12  imdb_title_id          1800 non-null   object
#  13  original_title         1800 non-null   object
#  14  year                   1800 non-null   int64
#  15  date_published         1800 non-null   object
#  16  genre                  1800 non-null   object
#  17  duration_imdb          1800 non-null   int64
#  18  country_imdb           1799 non-null   object
#  19  language               1786 non-null   object
#  20  writer                 1774 non-null   object
#  21  production_company     1753 non-null   object
#  22  actors                 1800 non-null   object
#  23  description_imdb       1800 non-null   object
#  24  avg_vote               1800 non-null   float64
#  25  votes                  1800 non-null   int64
#  26  budget                 743 non-null    object
#  27  usa_gross_income       767 non-null    object
#  28  worlwide_gross_income  1145 non-null   object
#  29  metascore              875 non-null    float64
#  30  reviews_from_users     1781 non-null   float64
#  31  reviews_from_critics   1709 non-null   float64
# dtypes: float64(4), int64(5), object(23)
# memory usage: 464.1+ KB

# %%
#check for mismatches between the two data sets
#different movies with the same title

combined_movie_df["title"].value_counts()
# Out:
# The Silence                        3
# Benji                              2
# The Lovers                         2
# The Outsider                       2
# Frank and Cindy                    2
#                                   ..
# Chameli                            1
# The Cloverfield Paradox            1
# Scream 2                           1
# Barsaat                            1
# The Goods: Live Hard, Sell Hard    1
# Name: title, Length: 1785, dtype: int64

# %%
# there are 15 entries that are duplicated
#probably because imdb has no director information
pd.options.display.max_rows = 1000 #this allows for full printing
duplicateDFRow = combined_movie_df[combined_movie_df["title"].duplicated()]
print(len(duplicateDFRow))
print(duplicateDFRow)
# Out:
# 15
#        show_id   type                title          director  \
# 198   81021082  Movie           Kuntilanak   Rizal Mantovani
# 388   81189912  Movie                Drive  Tarun Mansukhani
# 602   80152434  Movie         The Outsider  Martin Zandvliet
# 668   81072516  Movie               Sarkar   A.R. Murugadoss
# 682   80204923  Movie                Benji      Brandon Camp
# 777   80238292  Movie          The Silence    Gajendra Ahire
# 1112  80245041  Movie                 Solo       Hugo Stuven
# 1259  80038446  Movie           The Lovers      Roland Joffé
# 1279  80214583  Movie  People You May Know   Sherwin Shilati
# 1301  80209153  Movie          Blood Money       Lucky McKee
# 1483  70184051  Movie              One Day     Lone Scherfig
# 1490  70059026  Movie                  Don     Farhan Akhtar
# 1510  80093812  Movie                 Zoom     Pedro Morelli
# 1757  81021447  Movie          The Silence  John R. Leonetti
# 1799  80085439  Movie      Frank and Cindy  G.J. Echternkamp
#
#                                                    cast  \
# 198   Sandrinna M Skornicki, Aurélie Moeremans, Fero...
# 388   Jacqueline Fernandez, Sushant Singh Rajput, Bo...
# 602   Jared Leto, Tadanobu Asano, Kippei Shiina, Shi...
# 668   Vijay, Varalakshmi Sarathkumar, Keerthi Suresh...
# 682   Gabriel Bateman, Darby Camp, Kiele Sanchez, Je...
# 777   Raghuvir Yadav, Nagraj Manjule, Anjali Patil, ...
# 1112          Alain Hernández, Aura Garrido, Ben Temple
# 1259  Josh Hartnett, Bipasha Basu, Tamsin Egerton, J...
# 1279  Nick Thune, Halston Sage, Kaily Smith Westbroo...
# 1301  John Cusack, Ellar Coltrane, Willa Fitzgerald,...
# 1483  Rafe Spall, Jim Sturgess, Ken Stott, Jodie Whi...
# 1490  Shah Rukh Khan, Priyanka Chopra, Arjun Rampal,...
# 1510  Gael García Bernal, Alison Pill, Mariana Ximen...
# 1757  Stanley Tucci, Kiernan Shipka, Miranda Otto, K...
# 1799  Rene Russo, Oliver Platt, Johnny Simmons, Jane...
#
#                               country_net         date_added  release_year  \
# 198                             Indonesia   October 12, 2018          2018
# 388                                 India   November 1, 2019          2019
# 602                         United States      March 9, 2018          2018
# 668                                 India      March 2, 2019          2018
# 682   United Arab Emirates, United States     March 16, 2018          2018
# 777                                 India      March 1, 2018          2015
# 1112                                Spain   January 11, 2019          2018
# 1259            Belgium, India, Australia   February 5, 2017          2015
# 1279                        United States  February 26, 2018          2017
# 1301                        United States  February 17, 2018          2017
# 1483        United States, United Kingdom  December 16, 2018          2011
# 1490                                India  December 15, 2019          2006
# 1510                       Brazil, Canada  December 15, 2016          2015
# 1757                              Germany     April 10, 2019          2019
# 1799                        United States      April 1, 2016          2015
#
#      rating duration_net  ...  \
# 198   TV-14      106 min  ...
# 388   TV-14      119 min  ...
# 602   TV-MA      121 min  ...
# 668   TV-MA      162 min  ...
# 682   TV-PG       87 min  ...
# 777   TV-MA       91 min  ...
# 1112  TV-MA       91 min  ...
# 1259      R      109 min  ...
# 1279  TV-MA       92 min  ...
# 1301      R       85 min  ...
# 1483  PG-13      107 min  ...
# 1490  TV-MA      169 min  ...
# 1510     NR       93 min  ...
# 1757  TV-14       91 min  ...
# 1799      R      102 min  ...
#
#                                                  actors  \
# 198   Sandrinna Michelle, Aurélie Moeremans, Fero Wa...
# 388   Sushant Singh Rajput, Jacqueline Fernandez, Bo...
# 602   Jared Leto, Tadanobu Asano, Kippei Shîna, Shio...
# 668   Joseph Vijay, Keerthi Suresh, Varalaxmi Sarath...
# 682   Gabriel Bateman, Darby Camp, Kiele Sanchez, Gr...
# 777   Mugdha Chaphekar, Mihiresh Joshi, Kadambari Ka...
# 1112  Alain Hernández, Aura Garrido, Ben Temple, Let...
# 1259  Josh Hartnett, Bipasha Basu, Tamsin Egerton, J...
# 1279  Nick Thune, Halston Sage, Kaily Smith Westbroo...
# 1301  Ellar Coltrane, Willa Fitzgerald, Jacob Artist...
# 1483  Anne Hathaway, Jim Sturgess, Tom Mison, Jodie ...
# 1490  Shah Rukh Khan, Priyanka Chopra, Arjun Rampal,...
# 1510  Tyler Labine, Alison Pill, Michael Eklund, Mar...
# 1757  Stanley Tucci, Kiernan Shipka, Miranda Otto, K...
# 1799  Rene Russo, Oliver Platt, Johnny Simmons, Jane...
#
#                                        description_imdb avg_vote   votes  \
# 198   A group of kids agree to explore an abandoned ...      4.6     398
# 388   A stunt driver gets attracted to his neighbour...      2.3    2336
# 602   An epic set in post-WWII Japan and centered on...      6.3   17255
# 668   An NRI businessman learns his vote has been ca...      6.9   11503
# 682   Two school kids strike up a friendship with an...      6.4    3044
# 777   A young lady witnesses a crime in Mumbai which...      7.3     217
# 1112  After falling by a cliff on a desert beach, a ...      4.9    1779
# 1259  An epic, sweeping and riveting tale of an impo...      4.5    2923
# 1279  An introvert realizes he can be whomever he wa...      5.6    1235
# 1301  Three friends on a wilderness excursion must o...      4.5    1736
# 1483  After spending the night together on the night...      7.0  130494
# 1490  A simple man, Vijay, is recruited by a police ...      7.2   32331
# 1510  A multi-dimensional interface between a comic ...      6.1    2449
# 1757  When the world is under attack from terrifying...      5.2   28097
# 1799  G.J. Echternkamp tells the story of his relati...      6.1     593
#
#             budget usa_gross_income worlwide_gross_income  metascore  \
# 198            NaN              NaN                   NaN        NaN
# 388   INR 75000000              NaN                   NaN        NaN
# 602            NaN              NaN                $ 1869       30.0
# 668            NaN              NaN             $ 2278361        NaN
# 682      $ 6000000              NaN              $ 585333       53.0
# 777            NaN              NaN                   NaN        NaN
# 1112   EUR 2900000              NaN                   NaN        NaN
# 1259    $ 50000000              NaN               $ 66428       19.0
# 1279           NaN              NaN                   NaN        NaN
# 1301           NaN              NaN                   NaN       42.0
# 1483    $ 15000000       $ 13843771            $ 59389433       48.0
# 1490           NaN        $ 2223961            $ 19640129        NaN
# 1510           NaN              NaN                $ 2784       55.0
# 1757           NaN              NaN              $ 937795       25.0
# 1799           NaN              NaN                   NaN        NaN
#
#      reviews_from_users reviews_from_critics
# 198                12.0                 11.0
# 388               182.0                  9.0
# 602               175.0                 46.0
# 668               376.0                 13.0
# 682                42.0                 14.0
# 777                 3.0                  2.0
# 1112               18.0                 12.0
# 1259               25.0                 10.0
# 1279               11.0                  6.0
# 1301               40.0                 14.0
# 1483              212.0                223.0
# 1490              175.0                 28.0
# 1510               22.0                 30.0
# 1757              656.0                 84.0
# 1799                4.0                  3.0
#
# [15 rows x 32 columns]

# %%
#We drop the duplicated items

combined_movie_df = combined_movie_df.drop_duplicates(subset = ["title"])

combined_movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1785 entries, 0 to 1798
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   show_id                1785 non-null   int64
#  1   type                   1785 non-null   object
#  2   title                  1785 non-null   object
#  3   director               1785 non-null   object
#  4   cast                   1783 non-null   object
#  5   country_net            1781 non-null   object
#  6   date_added             1785 non-null   object
#  7   release_year           1785 non-null   int64
#  8   rating                 1784 non-null   object
#  9   duration_net           1785 non-null   object
#  10  listed_in              1785 non-null   object
#  11  description_net        1785 non-null   object
#  12  imdb_title_id          1785 non-null   object
#  13  original_title         1785 non-null   object
#  14  year                   1785 non-null   int64
#  15  date_published         1785 non-null   object
#  16  genre                  1785 non-null   object
#  17  duration_imdb          1785 non-null   int64
#  18  country_imdb           1784 non-null   object
#  19  language               1771 non-null   object
#  20  writer                 1760 non-null   object
#  21  production_company     1738 non-null   object
#  22  actors                 1785 non-null   object
#  23  description_imdb       1785 non-null   object
#  24  avg_vote               1785 non-null   float64
#  25  votes                  1785 non-null   int64
#  26  budget                 738 non-null    object
#  27  usa_gross_income       765 non-null    object
#  28  worlwide_gross_income  1137 non-null   object
#  29  metascore              868 non-null    float64
#  30  reviews_from_users     1766 non-null   float64
#  31  reviews_from_critics   1694 non-null   float64
# dtypes: float64(4), int64(5), object(23)
# memory usage: 460.2+ KB

# %%
# cut the columns that are missing a lot of information
#27 budget # 28 usa_gross_income #29 worlwide_gross_income #30 object metascore             
combined_movie_df = combined_movie_df[['show_id', 'type', 'title',
   'cast', 'country_net', 'date_added', 'release_year', 'rating', 'duration_net',
'listed_in', 'description_net', 'imdb_title_id', 'original_title', 'year',
'date_published', 'genre', 'duration_imdb', 'country_imdb', 'language', 'actors', 'description_imdb', 'avg_vote',
'votes']].copy()
combined_movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1785 entries, 0 to 1798
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   show_id           1785 non-null   int64
#  1   type              1785 non-null   object
#  2   title             1785 non-null   object
#  3   cast              1783 non-null   object
#  4   country_net       1781 non-null   object
#  5   date_added        1785 non-null   object
#  6   release_year      1785 non-null   int64
#  7   rating            1784 non-null   object
#  8   duration_net      1785 non-null   object
#  9   listed_in         1785 non-null   object
#  10  description_net   1785 non-null   object
#  11  imdb_title_id     1785 non-null   object
#  12  original_title    1785 non-null   object
#  13  year              1785 non-null   int64
#  14  date_published    1785 non-null   object
#  15  genre             1785 non-null   object
#  16  duration_imdb     1785 non-null   int64
#  17  country_imdb      1784 non-null   object
#  18  language          1771 non-null   object
#  19  actors            1785 non-null   object
#  20  description_imdb  1785 non-null   object
#  21  avg_vote          1785 non-null   float64
#  22  votes             1785 non-null   int64
# dtypes: float64(1), int64(5), object(17)
# memory usage: 334.7+ KB

# %%
#actors and cast are the same information, but cast is missing some data
# the two durations have the same infomation, but imdb duration is integer
#and netflix is missing some data, so we cut netflix
# release year and date published are the same, so we cut date_published

combined_movie_df = combined_movie_df[['show_id', 'type', 'title', 'date_added',
  'country_net' ,'release_year', 'rating',
'listed_in', 'description_net', 'imdb_title_id', 'original_title', 'year',
      'genre', 'duration_imdb',
'country_imdb', 'language', 'actors', 'description_imdb', 'avg_vote',
'votes']].copy()
combined_movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1785 entries, 0 to 1798
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   show_id           1785 non-null   int64
#  1   type              1785 non-null   object
#  2   title             1785 non-null   object
#  3   date_added        1785 non-null   object
#  4   country_net       1781 non-null   object
#  5   release_year      1785 non-null   int64
#  6   rating            1784 non-null   object
#  7   listed_in         1785 non-null   object
#  8   description_net   1785 non-null   object
#  9   imdb_title_id     1785 non-null   object
#  10  original_title    1785 non-null   object
#  11  year              1785 non-null   int64
#  12  genre             1785 non-null   object
#  13  duration_imdb     1785 non-null   int64
#  14  country_imdb      1784 non-null   object
#  15  language          1771 non-null   object
#  16  actors            1785 non-null   object
#  17  description_imdb  1785 non-null   object
#  18  avg_vote          1785 non-null   float64
#  19  votes             1785 non-null   int64
# dtypes: float64(1), int64(5), object(14)
# memory usage: 292.9+ KB

# %%
#Some columns are duplicated, so we check if we can complete the information
#by combining the columns
#Check if the country null values are missing in both columns
bool_series = pd.isnull(combined_movie_df['country_net']) 
bool_series = pd.isnull(combined_movie_df['country_imdb'])  
combined_movie_df[bool_series].T
# Out:
#                                                                 138
# show_id                                                    80211622
# type                                                          Movie
# title                                                  Been So Long
# date_added                                         October 26, 2018
# country_net                                                     NaN
# release_year                                                   2018
# rating                                                        TV-MA
# listed_in            Dramas, International Movies, Music & Musicals
# description_net   A single mother in London's Camden Town hears ...
# imdb_title_id                                             tt1682886
# original_title                                         Been So Long
# year                                                           2018
# genre                                       Drama, Musical, Romance
# duration_imdb                                                   100
# country_imdb                                                    NaN
# language                                                        NaN
# actors            Michaela Coel, Mya Lewis, Arinzé Kene, George ...
# description_imdb  A dedicated single mother who, on an unusual n...
# avg_vote                                                        5.5
# votes                                                           656

# %%
# the imdb database has more country data so we cut country_net
#both datasets are missing one piece of data so we replace it with not available
 
combined_movie_df["country_imdb"].fillna("Not Available", inplace = True)

combined_movie_df = combined_movie_df[['show_id', 'type', 'title', 'date_added', 'release_year', 'rating',
'listed_in', 'description_net', 'imdb_title_id', 'original_title', 'year', 'genre', 'duration_imdb', 'country_imdb', 'language', 'actors', 'description_imdb', 'avg_vote',
'votes']].copy()
combined_movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1785 entries, 0 to 1798
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   show_id           1785 non-null   int64
#  1   type              1785 non-null   object
#  2   title             1785 non-null   object
#  3   date_added        1785 non-null   object
#  4   release_year      1785 non-null   int64
#  5   rating            1785 non-null   object
#  6   listed_in         1785 non-null   object
#  7   description_net   1785 non-null   object
#  8   imdb_title_id     1785 non-null   object
#  9   original_title    1785 non-null   object
#  10  year              1785 non-null   int64
#  11  genre             1785 non-null   object
#  12  duration_imdb     1785 non-null   int64
#  13  country_imdb      1785 non-null   object
#  14  language          1771 non-null   object
#  15  actors            1785 non-null   object
#  16  description_imdb  1785 non-null   object
#  17  avg_vote          1785 non-null   float64
#  18  votes             1785 non-null   int64
# dtypes: float64(1), int64(5), object(13)
# memory usage: 278.9+ KB

# %%
# fill the missing rating as "not available"
combined_movie_df["rating"].fillna("Not Available", inplace = True)

# %%
combined_movie_df[['year','release_year']]
# Out:
#       year  release_year
# 0     2019          2019
# 1     2014          2014
# 2     2015          2015
# 3     2015          2015
# 4     2015          2014
# ...    ...           ...
# 1794  2016          2016
# 1795  2015          2015
# 1796  2014          2014
# 1797  2016          2016
# 1798  2015          2007
#
# [1785 rows x 2 columns]

# %%
# gains = df[df.buy_price < df.sell_price]
different = combined_movie_df.year != combined_movie_df.release_year
different.value_counts()
# Out:
# False    1701
# True       84
# dtype: int64

# %%
combined_movie_df.head(1798)
# Out:
#        show_id   type                                    title  \
# 0     81145628  Movie  Norm of the North: King Sized Adventure
# 1     70304990  Movie                              Good People
# 2     70299204  Movie                  Kidnapping Mr. Heineken
# 3     80057969  Movie                                     Love
# 4     80060297  Movie                        Manhattan Romance
# ...        ...    ...                                      ...
# 1794  80115101  Movie                                   Deuces
# 1795  80081955  Movie                     Five Nights in Maine
# 1796  70302835  Movie                                    Killa
# 1797  80125512  Movie                                 Lavender
# 1798  80085438  Movie                          Frank and Cindy
#
#              date_added                                        country_net  \
# 0     September 9, 2019           United States, India, South Korea, China
# 1     September 8, 2017     United States, United Kingdom, Denmark, Sweden
# 2     September 8, 2017  Netherlands, Belgium, United Kingdom, United S...
# 3     September 8, 2017                                    France, Belgium
# 4     September 8, 2017                                      United States
# ...                 ...                                                ...
# 1794      April 1, 2017                                      United States
# 1795      April 1, 2017                                      United States
# 1796      April 1, 2017                                              India
# 1797      April 1, 2017                              Canada, United States
# 1798      April 1, 2016                                      United States
#
#       release_year rating                                         listed_in  \
# 0             2019  TV-PG                Children & Family Movies, Comedies
# 1             2014      R                     Action & Adventure, Thrillers
# 2             2015      R  Action & Adventure, Dramas, International Movies
# 3             2015     NR           Cult Movies, Dramas, Independent Movies
# 4             2014  TV-14     Comedies, Independent Movies, Romantic Movies
# ...            ...    ...                                               ...
# 1794          2016  TV-MA                                            Dramas
# 1795          2015  TV-14                        Dramas, Independent Movies
# 1796          2014  TV-14                      Dramas, International Movies
# 1797          2016     NR           Dramas, International Movies, Thrillers
# 1798          2007  TV-MA                                     Documentaries
#
#                                         description_net imdb_title_id  \
# 0     Before planning an awesome wedding for his gra...     tt9428190
# 1     A struggling couple can't believe their luck w...     tt1361318
# 2     When beer magnate Alfred "Freddy" Heineken is ...     tt2917388
# 3     A man in an unsatisfying marriage recalls the ...     tt3774694
# 4     A filmmaker working on a documentary about lov...     tt2608324
# ...                                                 ...           ...
# 1794  Assigned to go undercover to take down an impe...     tt5081606
# 1795  After his wife dies in a car accident, a grief...     tt3352034
# 1796  Growing up poses challenges for Chinu when he ...     tt3341582
# 1797  After discovering old fractures in her skull, ...     tt4680980
# 1798  Frank was a rising pop star when he married Ci...     tt1239242
#
#                                original_title  year  \
# 0     Norm of the North: King Sized Adventure  2019
# 1                                 Good People  2014
# 2                     Kidnapping Mr. Heineken  2015
# 3                                        Love  2015
# 4                           Manhattan Romance  2015
# ...                                       ...   ...
# 1794                                   Deuces  2016
# 1795                     Five Nights in Maine  2015
# 1796                                    Killa  2014
# 1797                                 Lavender  2016
# 1798                          Frank and Cindy  2015
#
#                              genre  duration_imdb  \
# 0     Animation, Adventure, Comedy             90
# 1          Action, Crime, Thriller             90
# 2             Action, Crime, Drama             95
# 3                   Drama, Romance            135
# 4           Comedy, Drama, Romance             94
# ...                            ...            ...
# 1794          Action, Crime, Drama             87
# 1795                         Drama             82
# 1796                 Comedy, Drama            107
# 1797               Drama, Thriller             92
# 1798                        Comedy            102
#
#                         country_imdb                language  \
# 0     USA, India, South Korea, China                 English
# 1           USA, UK, Denmark, Sweden                 English
# 2      Netherlands, Belgium, UK, USA  English, Dutch, German
# 3                    France, Belgium         English, French
# 4                                USA                 English
# ...                              ...                     ...
# 1794                             USA                 English
# 1795                             USA                 English
# 1796                           India                 Marathi
# 1797                     Canada, USA                 English
# 1798                             USA                 English
#
#                                                  actors  \
# 0     Jennifer Cameron, Brian Dobson, Michael Dobson...
# 1     Sam Spruell, Michael Fox, Diarmaid Murtagh, Fr...
# 2     Jim Sturgess, Sam Worthington, Ryan Kwanten, A...
# 3     Aomi Muyock, Karl Glusman, Klara Kristin, Ugo ...
# 4     Arnold C. Baker II, Jessie Barr, Tommy Burke, ...
# ...                                                 ...
# 1794  Larenz Tate, Meagan Good, Rotimi, Rick Gonzale...
# 1795  David Oyelowo, Hani Furstenberg, Neal Lerner, ...
# 1796  Amruta Subhash, Archit Deodhar, Parth Bhalerao...
# 1797  Abbie Cornish, Dermot Mulroney, Justin Long, L...
# 1798  Rene Russo, Oliver Platt, Johnny Simmons, Jane...
#
#                                        description_imdb  avg_vote  votes
# 0     An ancient Chinese artifact has been stolen by...       3.2    185
# 1     Discovering a stash of cash in their dead tena...       5.5  14655
# 2     The inside story of the planning, execution, r...       6.1  18168
# 3     Murphy is an American living in Paris who ente...       6.1  39385
# 4     Danny, a commercial editor and documentary fil...       5.5   1082
# ...                                                 ...       ...    ...
# 1794  An undercover agent infiltrates a crime ring r...       5.9    790
# 1795  A young African American man, reeling from the...       4.5    617
# 1796  A 11-year-old Indian boy who has just lost his...       8.0   1170
# 1797  After discovering old fractures in her skull, ...       5.3   5083
# 1798  G.J. Echternkamp tells the story of his relati...       6.1    593
#
# [1785 rows x 20 columns]

# %%
# if we need to find additional data we can use this package
# pip install imdbpy

# %%
# This is the code we used in class for cleaning data and exporting it

# %% [markdown]
# ### Transform premise DataFrame

# %%
new_premise_df = premise_df[['Premises Name', 'County ID Code']].copy()
new_premise_df.head()

# %%
new_premise_df.rename(columns = {'Premises Name':'premise_name'}, inplace = True)

# %%
new_premise_df.rename(columns = {'County ID Code':'county_id'}, inplace = True) 
new_premise_df.duplicated()
new_premise_df.drop_duplicates(['premise_name'])

# %% [markdown]
# ### Transform county DataFrame

# %%
county_df.head()
new_county_df = county_df[['County Name (Licensee)', 'County ID Code', 'License Count']].copy()
new_county_df.count()

# %%
new_county_df.rename(columns = {'License Count':'license_count',
                               "County Name (Licensee)": "county_name",
                               "County ID Code": "county_id"}, inplace = True) 

# A `county` table that contains the columns `id`, `county_name`, 
#     `license_count` and `county_id`.
new_county_df

# %% [markdown]
# ### Create database connection

# %%
rds_connection_string = "postgres:1117@localhost:5432/customer_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Confirm tables
engine.table_names()

# %% [markdown]
# ### Load DataFrames into database

# %%
new_county_df.to_sql(name='county', con=engine, if_exists='append', index=False)

# %%
new_premise_df.to_sql(name='premise', con=engine, if_exists='append', index=False)
