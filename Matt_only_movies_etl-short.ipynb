# %%
import pandas as pd
from sqlalchemy import create_engine

# this allows for full display without using print statements
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
# import the imdb data
imdb_file = "IMDb movies.csv"
imdb_df = pd.read_csv(imdb_file)
imdb_df.head()
# Out:
#   imdb_title_id                                              title  \
# 0     tt0000574                        The Story of the Kelly Gang
# 1     tt0001892                                     Den sorte drøm
# 2     tt0002101                                          Cleopatra
# 3     tt0002130                                          L'Inferno
# 4     tt0002199  From the Manger to the Cross; or, Jesus of Naz...
#
#                                       original_title  year date_published  \
# 0                        The Story of the Kelly Gang  1906     1906-12-26
# 1                                     Den sorte drøm  1911     1911-08-19
# 2                                          Cleopatra  1912     1912-11-13
# 3                                          L'Inferno  1911     1911-03-06
# 4  From the Manger to the Cross; or, Jesus of Naz...  1912           1913
#
#                        genre  duration           country language  \
# 0    Biography, Crime, Drama        70         Australia      NaN
# 1                      Drama        53  Germany, Denmark      NaN
# 2             Drama, History       100               USA  English
# 3  Adventure, Drama, Fantasy        68             Italy  Italian
# 4           Biography, Drama        60               USA  English
#
#                               director  ...  \
# 0                         Charles Tait  ...
# 1                            Urban Gad  ...
# 2                   Charles L. Gaskill  ...
# 3  Francesco Bertolini, Adolfo Padovan  ...
# 4                        Sidney Olcott  ...
#
#                                               actors  \
# 0  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 1  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 2  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 3  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
# 4  R. Henderson Bland, Percy Dyer, Gene Gauntier,...
#
#                                          description avg_vote votes   budget  \
# 0  True story of notorious Australian outlaw Ned ...      6.1   537   $ 2250
# 1  Two men of high rank are both wooing the beaut...      5.9   171      NaN
# 2  The fabled queen of Egypt's affair with Roman ...      5.2   420  $ 45000
# 3  Loosely adapted from Dante's Divine Comedy and...      7.0  2019      NaN
# 4  An account of the life of Jesus Christ, based ...      5.7   438      NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                7.0
# 1               NaN                   NaN       NaN                4.0
# 2               NaN                   NaN       NaN               24.0
# 3               NaN                   NaN       NaN               28.0
# 4               NaN                   NaN       NaN               12.0
#
#    reviews_from_critics
# 0                   7.0
# 1                   2.0
# 2                   3.0
# 3                  14.0
# 4                   5.0
#
# [5 rows x 22 columns]

# %%
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81273 entries, 0 to 81272
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          81273 non-null  object
#  1   title                  81273 non-null  object
#  2   original_title         81273 non-null  object
#  3   year                   81273 non-null  int64
#  4   date_published         81273 non-null  object
#  5   genre                  81273 non-null  object
#  6   duration               81273 non-null  int64
#  7   country                81234 non-null  object
#  8   language               80518 non-null  object
#  9   director               81200 non-null  object
#  10  writer                 79780 non-null  object
#  11  production_company     76948 non-null  object
#  12  actors                 81207 non-null  object
#  13  description            78843 non-null  object
#  14  avg_vote               81273 non-null  float64
#  15  votes                  81273 non-null  int64
#  16  budget                 22804 non-null  object
#  17  usa_gross_income       15094 non-null  object
#  18  worlwide_gross_income  29892 non-null  object
#  19  metascore              12722 non-null  float64
#  20  reviews_from_users     74196 non-null  float64
#  21  reviews_from_critics   70286 non-null  float64
# dtypes: float64(4), int64(3), object(15)
# memory usage: 13.6+ MB

# %%
# import the netflix data
netflix_file = "netflix_titles.csv"
netflix_df = pd.read_csv(netflix_file)
netflix_df.head()
netflix_df.info()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 1                            United Kingdom  September 9, 2016          2016
# 2                             United States  September 8, 2018          2013
# 3                             United States  September 8, 2018          2016
# 4                             United States  September 8, 2017          2017
#
#      rating  duration                           listed_in  \
# 0     TV-PG    90 min  Children & Family Movies, Comedies
# 1     TV-MA    94 min                     Stand-Up Comedy
# 2  TV-Y7-FV  1 Season                            Kids' TV
# 3     TV-Y7  1 Season                            Kids' TV
# 4     TV-14    99 min                            Comedies
#
#                                          description
# 0  Before planning an awesome wedding for his gra...
# 1  Jandino Asporaat riffs on the challenges of ra...
# 2  With the help of three human allies, the Autob...
# 3  When a prison ship crash unleashes hundreds of...
# 4  When nerdy high schooler Dani finally attracts...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6234 entries, 0 to 6233
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6234 non-null   int64
#  1   type          6234 non-null   object
#  2   title         6234 non-null   object
#  3   director      4265 non-null   object
#  4   cast          5664 non-null   object
#  5   country       5758 non-null   object
#  6   date_added    6223 non-null   object
#  7   release_year  6234 non-null   int64
#  8   rating        6224 non-null   object
#  9   duration      6234 non-null   object
#  10  listed_in     6234 non-null   object
#  11  description   6234 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 584.6+ KB

# %%
#split the netflix data intp movies and TV shows
netflix_movies_df = netflix_df.loc[netflix_df['type']=='Movie',:]
netflix_movies_df.info()
netflix_TV_df = netflix_df.loc[netflix_df['type']=='TV Show']
netflix_TV_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4265 entries, 0 to 6231
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       4265 non-null   int64
#  1   type          4265 non-null   object
#  2   title         4265 non-null   object
#  3   director      4137 non-null   object
#  4   cast          3905 non-null   object
#  5   country       4070 non-null   object
#  6   date_added    4264 non-null   object
#  7   release_year  4265 non-null   int64
#  8   rating        4257 non-null   object
#  9   duration      4265 non-null   object
#  10  listed_in     4265 non-null   object
#  11  description   4265 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 433.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1969 entries, 2 to 6233
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       1969 non-null   int64
#  1   type          1969 non-null   object
#  2   title         1969 non-null   object
#  3   director      128 non-null    object
#  4   cast          1759 non-null   object
#  5   country       1688 non-null   object
#  6   date_added    1959 non-null   object
#  7   release_year  1969 non-null   int64
#  8   rating        1967 non-null   object
#  9   duration      1969 non-null   object
#  10  listed_in     1969 non-null   object
#  11  description   1969 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 200.0+ KB

# %%
#check for missing directors in the data
bool_series = pd.isnull(netflix_movies_df["director"])  
print (f"There are {len(netflix_movies_df[bool_series])} movies with no director information") 
bool_series = pd.isnull(netflix_TV_df["director"])  
print (f"There are {len(netflix_TV_df[bool_series])} TV Shows with no director information")
# Out:
# There are 128 movies with no director information
# There are 1841 TV Shows with no director information

# %%
`
# Out:
#   File "<ipython-input-59-f6460d7d9d2b>", line 1
#     `
#     ^
# SyntaxError: invalid syntax

# %%
# merge the two data sets
#merging on title produces mismatches between the data, so merge on title and director

combined_movie_df = pd.merge(netflix_movies_df, imdb_df, left_on=['title','director'], 
                    right_on=['title','director'], suffixes=('_net', '_imdb') )
type(combined_movie_df)
# Out:
# pandas.core.frame.DataFrame

# %%
#check for mismatchews between the two data sets

combined_movie_df["title"].value_counts()
# Out:
# The Silence                       3
# The Outsider                      2
# Don                               2
# Blood Money                       2
# Drive                             2
#                                  ..
# The Journey Is the Destination    1
# Hop                               1
# Nasha                             1
# Satyagraha                        1
# 20th Century Women                1
# Name: title, Length: 1785, dtype: int64

# %%
# there are 15 entries that are duplicated (becaise imdb has ni director information
pd.options.display.max_rows = 1000 #this allows for full printing
duplicateDFRow = combined_movie_df[combined_movie_df["title"].duplicated()]
print(duplicateDFRow.T)
# Out:
#                                                                     198   \
# show_id                                                         81021082
# type                                                               Movie
# title                                                         Kuntilanak
# director                                                 Rizal Mantovani
# cast                   Sandrinna M Skornicki, Aurélie Moeremans, Fero...
# country_net                                                    Indonesia
# date_added                                              October 12, 2018
# release_year                                                        2018
# rating                                                             TV-14
# duration_net                                                     106 min
# listed_in                            Horror Movies, International Movies
# description_net        Five youngsters discover that an antique mirro...
# imdb_title_id                                                  tt8512746
# original_title                                                Kuntilanak
# year                                                                2018
# date_published                                                2018-06-15
# genre                                                     Comedy, Horror
# duration_imdb                                                        105
# country_imdb                                                   Indonesia
# language                                                      Indonesian
# writer                                                        Alim Sudio
# production_company                                          MVP Pictures
# actors                 Sandrinna Michelle, Aurélie Moeremans, Fero Wa...
# description_imdb       A group of kids agree to explore an abandoned ...
# avg_vote                                                             4.6
# votes                                                                398
# budget                                                               NaN
# usa_gross_income                                                     NaN
# worlwide_gross_income                                                NaN
# metascore                                                            NaN
# reviews_from_users                                                    12
# reviews_from_critics                                                  11
#
#                                                                     388   \
# show_id                                                         81189912
# type                                                               Movie
# title                                                              Drive
# director                                                Tarun Mansukhani
# cast                   Jacqueline Fernandez, Sushant Singh Rajput, Bo...
# country_net                                                        India
# date_added                                              November 1, 2019
# release_year                                                        2019
# rating                                                             TV-14
# duration_net                                                     119 min
# listed_in                       Action & Adventure, International Movies
# description_net        A notorious thief allies with a street racer f...
# imdb_title_id                                                  tt6593054
# original_title                                                     Drive
# year                                                                2019
# date_published                                                2019-11-01
# genre                                                   Action, Thriller
# duration_imdb                                                        147
# country_imdb                                                       India
# language                                                           Hindi
# writer                                           Mast Ali, Hossein Amini
# production_company                                    Dharma Productions
# actors                 Sushant Singh Rajput, Jacqueline Fernandez, Bo...
# description_imdb       A stunt driver gets attracted to his neighbour...
# avg_vote                                                             2.3
# votes                                                               2336
# budget                                                      INR 75000000
# usa_gross_income                                                     NaN
# worlwide_gross_income                                                NaN
# metascore                                                            NaN
# reviews_from_users                                                   182
# reviews_from_critics                                                   9
#
#                                                                     602   \
# show_id                                                         80152434
# type                                                               Movie
# title                                                       The Outsider
# director                                                Martin Zandvliet
# cast                   Jared Leto, Tadanobu Asano, Kippei Shiina, Shi...
# country_net                                                United States
# date_added                                                 March 9, 2018
# release_year                                                        2018
# rating                                                             TV-MA
# duration_net                                                     121 min
# listed_in                                              Dramas, Thrillers
# description_net        An American soldier imprisoned in postwar Japa...
# imdb_title_id                                                  tt2011311
# original_title                                              The Outsider
# year                                                                2018
# date_published                                                2018-03-09
# genre                                             Crime, Drama, Thriller
# duration_imdb                                                        120
# country_imdb                                                         USA
# language                                               English, Japanese
# writer                                                    Andrew Baldwin
# production_company                                  Linson Entertainment
# actors                 Jared Leto, Tadanobu Asano, Kippei Shîna, Shio...
# description_imdb       An epic set in post-WWII Japan and centered on...
# avg_vote                                                             6.3
# votes                                                              17255
# budget                                                               NaN
# usa_gross_income                                                     NaN
# worlwide_gross_income                                             $ 1869
# metascore                                                             30
# reviews_from_users                                                   175
# reviews_from_critics                                                  46
#
#                                                                     668   \
# show_id                                                         81072516
# type                                                               Movie
# title                                                             Sarkar
# director                                                 A.R. Murugadoss
# cast                   Vijay, Varalakshmi Sarathkumar, Keerthi Suresh...
# country_net                                                        India
# date_added                                                 March 2, 2019
# release_year                                                        2018
# rating                                                             TV-MA
# duration_net                                                     162 min
# listed_in               Action & Adventure, Dramas, International Movies
# description_net        A ruthless businessman’s mission to expose ele...
# imdb_title_id                                                  tt7715202
# original_title                                                    Sarkar
# year                                                                2018
# date_published                                                2018-11-06
# genre                                                      Action, Drama
# duration_imdb                                                        163
# country_imdb                                                       India
# language                                                   Tamil, Telugu
# writer                                        Jayamohan, A.R. Murugadoss
# production_company                                          Sun Pictures
# actors                 Joseph Vijay, Keerthi Suresh, Varalaxmi Sarath...
# description_imdb       An NRI businessman learns his vote has been ca...
# avg_vote                                                             6.9
# votes                                                              11503
# budget                                                               NaN
# usa_gross_income                                                     NaN
# worlwide_gross_income                                          $ 2278361
# metascore                                                            NaN
# reviews_from_users                                                   376
# reviews_from_critics                                                  13
#
#                                                                     682   \
# show_id                                                         80204923
# type                                                               Movie
# title                                                              Benji
# director                                                    Brandon Camp
# cast                   Gabriel Bateman, Darby Camp, Kiele Sanchez, Je...
# country_net                          United Arab Emirates, United States
# date_added                                                March 16, 2018
# release_year                                                        2018
# rating                                                             TV-PG
# duration_net                                                      87 min
# listed_in                               Children & Family Movies, Dramas
# description_net        A determined dog comes to the rescue and helps...
# imdb_title_id                                                  tt1799516
# original_title                                                     Benji
# year                                                                2018
# date_published                                                2018-03-16
# genre                                               Crime, Drama, Family
# duration_imdb                                                         87
# country_imdb                                   United Arab Emirates, USA
# language                                                         English
# writer                                            Brandon Camp, Joe Camp
# production_company                                 Blumhouse Productions
# actors                 Gabriel Bateman, Darby Camp, Kiele Sanchez, Gr...
# description_imdb       Two school kids strike up a friendship with an...
# avg_vote                                                             6.4
# votes                                                               3044
# budget                                                         $ 6000000
# usa_gross_income                                                     NaN
# worlwide_gross_income                                           $ 585333
# metascore                                                             53
# reviews_from_users                                                    42
# reviews_from_critics                                                  14
#
#                                                                     777   \
# show_id                                                         80238292
# type                                                               Movie
# title                                                        The Silence
# director                                                  Gajendra Ahire
# cast                   Raghuvir Yadav, Nagraj Manjule, Anjali Patil, ...
# country_net                                                        India
# date_added                                                 March 1, 2018
# release_year                                                        2015
# rating                                                             TV-MA
# duration_net                                                      91 min
# listed_in                                   Dramas, International Movies
# description_net        After encountering a scene of sexual violence,...
# imdb_title_id                                                  tt4603640
# original_title                                               The Silence
# year                                                                2015
# date_published                                                2017-10-06
# genre                                                              Drama
# duration_imdb                                                         91
# country_imdb                                                       India
# language                                                  Hindi, Marathi
# writer                                                               NaN
# production_company                                             SMR Films
# actors                 Mugdha Chaphekar, Mihiresh Joshi, Kadambari Ka...
# description_imdb       A young lady witnesses a crime in Mumbai which...
# avg_vote                                                             7.3
# votes                                                                217
# budget                                                               NaN
# usa_gross_income                                                     NaN
# worlwide_gross_income                                                NaN
# metascore                                                            NaN
# reviews_from_users                                                     3
# reviews_from_critics                                                   2
#
#                                                                     1112  \
# show_id                                                         80245041
# type                                                               Movie
# title                                                               Solo
# director                                                     Hugo Stuven
# cast                           Alain Hernández, Aura Garrido, Ben Temple
# country_net                                                        Spain
# date_added                                              January 11, 2019
# release_year                                                        2018
# rating                                                             TV-MA
# duration_net                                                      91 min
# listed_in               Dramas, Independent Movies, International Movies
# description_net        In a remote area of the Canary Islands, a surf...
# imdb_title_id                                                  tt6699860
# original_title                                                      Solo
# year                                                                2018
# date_published                                                2018-08-03
# genre                                          Adventure, Drama, Romance
# duration_imdb                                                         91
# country_imdb                                                       Spain
# language                                                         Spanish
# writer                                     Santiago Lallana, Hugo Stuven
# production_company                                   Fargo Entertainment
# actors                 Alain Hernández, Aura Garrido, Ben Temple, Let...
# description_imdb       After falling by a cliff on a desert beach, a ...
# avg_vote                                                             4.9
# votes                                                               1779
# budget                                                       EUR 2900000
# usa_gross_income                                                     NaN
# worlwide_gross_income                                                NaN
# metascore                                                            NaN
# reviews_from_users                                                    18
# reviews_from_critics                                                  12
#
#                                                                     1259  \
# show_id                                                         80038446
# type                                                               Movie
# title                                                         The Lovers
# director                                                    Roland Joffé
# cast                   Josh Hartnett, Bipasha Basu, Tamsin Egerton, J...
# country_net                                    Belgium, India, Australia
# date_added                                              February 5, 2017
# release_year                                                        2015
# rating                                                                 R
# duration_net                                                     109 min
# listed_in                 Action & Adventure, Dramas, Independent Movies
# description_net        A magical ring holds the key to life, death an...
# imdb_title_id                                                  tt1321869
# original_title                                                The Lovers
# year                                                                2013
# date_published                                                2015-02-13
# genre                                         Action, Adventure, Romance
# duration_imdb                                                        109
# country_imdb                                   Belgium, India, Australia
# language                                                  English, Hindi
# writer                                        Ajey Jhankar, Roland Joffé
# production_company                                                Corsan
# actors                 Josh Hartnett, Bipasha Basu, Tamsin Egerton, J...
# description_imdb       An epic, sweeping and riveting tale of an impo...
# avg_vote                                                             4.5
# votes                                                               2923
# budget                                                        $ 50000000
# usa_gross_income                                                     NaN
# worlwide_gross_income                                            $ 66428
# metascore                                                             19
# reviews_from_users                                                    25
# reviews_from_critics                                                  10
#
#                                                                     1279  \
# show_id                                                         80214583
# type                                                               Movie
# title                                                People You May Know
# director                                                 Sherwin Shilati
# cast                   Nick Thune, Halston Sage, Kaily Smith Westbroo...
# country_net                                                United States
# date_added                                             February 26, 2018
# release_year                                                        2017
# rating                                                             TV-MA
# duration_net                                                      92 min
# listed_in                              Comedies, Dramas, Romantic Movies
# description_net        A shy luddite gains fame, attention and friend...
# imdb_title_id                                                  tt5318534
# original_title                                       People You May Know
# year                                                                2017
# date_published                                                2017-04-07
# genre                                             Comedy, Drama, Romance
# duration_imdb                                                         92
# country_imdb                                                         USA
# language                                                         English
# writer                                    Michael Mohan, Sherwin Shilati
# production_company                             Red Ladders Entertainment
# actors                 Nick Thune, Halston Sage, Kaily Smith Westbroo...
# description_imdb       An introvert realizes he can be whomever he wa...
# avg_vote                                                             5.6
# votes                                                               1235
# budget                                                               NaN
# usa_gross_income                                                     NaN
# worlwide_gross_income                                                NaN
# metascore                                                            NaN
# reviews_from_users                                                    11
# reviews_from_critics                                                   6
#
#                                                                     1301  \
# show_id                                                         80209153
# type                                                               Movie
# title                                                        Blood Money
# director                                                     Lucky McKee
# cast                   John Cusack, Ellar Coltrane, Willa Fitzgerald,...
# country_net                                                United States
# date_added                                             February 17, 2018
# release_year                                                        2017
# rating                                                                 R
# duration_net                                                      85 min
# listed_in                                             Action & Adventure
# description_net        Three friends on a wilderness trip find bags f...
# imdb_title_id                                                  tt3758852
# original_title                                               Blood Money
# year                                                                2017
# date_published                                                2017-10-13
# genre                                             Crime, Drama, Thriller
# duration_imdb                                                        100
# country_imdb                                                         USA
# language                                                         English
# writer                                        Jared Butler, Lars Norberg
# production_company                                   Envision Media Arts
# actors                 Ellar Coltrane, Willa Fitzgerald, Jacob Artist...
# description_imdb       Three friends on a wilderness excursion must o...
# avg_vote                                                             4.5
# votes                                                               1736
# budget                                                               NaN
# usa_gross_income                                                     NaN
# worlwide_gross_income                                                NaN
# metascore                                                             42
# reviews_from_users                                                    40
# reviews_from_critics                                                  14
#
#                                                                     1483  \
# show_id                                                         70184051
# type                                                               Movie
# title                                                            One Day
# director                                                   Lone Scherfig
# cast                   Rafe Spall, Jim Sturgess, Ken Stott, Jodie Whi...
# country_net                                United States, United Kingdom
# date_added                                             December 16, 2018
# release_year                                                        2011
# rating                                                             PG-13
# duration_net                                                     107 min
# listed_in                                        Dramas, Romantic Movies
# description_net        After a brief college romance, Emma and Dexter...
# imdb_title_id                                                  tt1563738
# original_title                                                   One Day
# year                                                                2011
# date_published                                                2011-08-26
# genre                                                     Drama, Romance
# duration_imdb                                                        107
# country_imdb                                                     USA, UK
# language                                                         English
# writer                                    David Nicholls, David Nicholls
# production_company                                        Focus Features
# actors                 Anne Hathaway, Jim Sturgess, Tom Mison, Jodie ...
# description_imdb       After spending the night together on the night...
# avg_vote                                                               7
# votes                                                             130494
# budget                                                        $ 15000000
# usa_gross_income                                              $ 13843771
# worlwide_gross_income                                         $ 59389433
# metascore                                                             48
# reviews_from_users                                                   212
# reviews_from_critics                                                 223
#
#                                                                     1490  \
# show_id                                                         70059026
# type                                                               Movie
# title                                                                Don
# director                                                   Farhan Akhtar
# cast                   Shah Rukh Khan, Priyanka Chopra, Arjun Rampal,...
# country_net                                                        India
# date_added                                             December 15, 2019
# release_year                                                        2006
# rating                                                             TV-MA
# duration_net                                                     169 min
# listed_in                       Action & Adventure, International Movies
# description_net        A ruthless crime boss and drug lord is nabbed ...
# imdb_title_id                                                  tt0461936
# original_title                                                       Don
# year                                                                2006
# date_published                                                2006-10-20
# genre                                            Action, Crime, Thriller
# duration_imdb                                                        171
# country_imdb                                                       India
# language                                                           Hindi
# writer                                          Salim Khan, Javed Akhtar
# production_company                                   Excel Entertainment
# actors                 Shah Rukh Khan, Priyanka Chopra, Arjun Rampal,...
# description_imdb       A simple man, Vijay, is recruited by a police ...
# avg_vote                                                             7.2
# votes                                                              32331
# budget                                                               NaN
# usa_gross_income                                               $ 2223961
# worlwide_gross_income                                         $ 19640129
# metascore                                                            NaN
# reviews_from_users                                                   175
# reviews_from_critics                                                  28
#
#                                                                     1510  \
# show_id                                                         80093812
# type                                                               Movie
# title                                                               Zoom
# director                                                   Pedro Morelli
# cast                   Gael García Bernal, Alison Pill, Mariana Ximen...
# country_net                                               Brazil, Canada
# date_added                                             December 15, 2016
# release_year                                                        2015
# rating                                                                NR
# duration_net                                                      93 min
# listed_in                           Comedies, Dramas, Independent Movies
# description_net        Comic book artist Emma draws her ideal man: Ed...
# imdb_title_id                                                  tt3763866
# original_title                                                      Zoom
# year                                                                2015
# date_published                                                2016-03-31
# genre                                           Animation, Comedy, Drama
# duration_imdb                                                         96
# country_imdb                                              Brazil, Canada
# language                                             Portuguese, English
# writer                                        Matt Hansen, Pedro Morelli
# production_company                                         Rhombus Media
# actors                 Tyler Labine, Alison Pill, Michael Eklund, Mar...
# description_imdb       A multi-dimensional interface between a comic ...
# avg_vote                                                             6.1
# votes                                                               2449
# budget                                                               NaN
# usa_gross_income                                                     NaN
# worlwide_gross_income                                             $ 2784
# metascore                                                             55
# reviews_from_users                                                    22
# reviews_from_critics                                                  30
#
#                                                                     1757  \
# show_id                                                         81021447
# type                                                               Movie
# title                                                        The Silence
# director                                                John R. Leonetti
# cast                   Stanley Tucci, Kiernan Shipka, Miranda Otto, K...
# country_net                                                      Germany
# date_added                                                April 10, 2019
# release_year                                                        2019
# rating                                                             TV-14
# duration_net                                                      91 min
# listed_in                                       Horror Movies, Thrillers
# description_net        With the world under attack by deadly creature...
# imdb_title_id                                                  tt7315484
# original_title                                               The Silence
# year                                                                2019
# date_published                                                2019-04-10
# genre                                              Drama, Horror, Sci-Fi
# duration_imdb                                                         90
# country_imdb                                                Germany, USA
# language                                 English, American Sign Language
# writer                                    Carey Van Dyke, Shane Van Dyke
# production_company                                       Constantin Film
# actors                 Stanley Tucci, Kiernan Shipka, Miranda Otto, K...
# description_imdb       When the world is under attack from terrifying...
# avg_vote                                                             5.2
# votes                                                              28097
# budget                                                               NaN
# usa_gross_income                                                     NaN
# worlwide_gross_income                                           $ 937795
# metascore                                                             25
# reviews_from_users                                                   656
# reviews_from_critics                                                  84
#
#                                                                     1799
# show_id                                                         80085439
# type                                                               Movie
# title                                                    Frank and Cindy
# director                                                G.J. Echternkamp
# cast                   Rene Russo, Oliver Platt, Johnny Simmons, Jane...
# country_net                                                United States
# date_added                                                 April 1, 2016
# release_year                                                        2015
# rating                                                                 R
# duration_net                                                     102 min
# listed_in                           Comedies, Dramas, Independent Movies
# description_net        A student filmmaker vengefully turns his camer...
# imdb_title_id                                                  tt1239242
# original_title                                           Frank and Cindy
# year                                                                2015
# date_published                                                2016-04-01
# genre                                                             Comedy
# duration_imdb                                                        102
# country_imdb                                                         USA
# language                                                         English
# writer                                G.J. Echternkamp, G.J. Echternkamp
# production_company                                     Lleju Productions
# actors                 Rene Russo, Oliver Platt, Johnny Simmons, Jane...
# description_imdb       G.J. Echternkamp tells the story of his relati...
# avg_vote                                                             6.1
# votes                                                                593
# budget                                                               NaN
# usa_gross_income                                                     NaN
# worlwide_gross_income                                                NaN
# metascore                                                            NaN
# reviews_from_users                                                     4
# reviews_from_critics                                                   3

# %%
#We can drop the duplivated items or try to save some data

combined_movie_df = combined_movie_df.drop_duplicates(subset = ["title"])

combined_movie_df
# Out:
#        show_id   type                                    title  \
# 0     81145628  Movie  Norm of the North: King Sized Adventure
# 1     70304990  Movie                              Good People
# 2     70299204  Movie                  Kidnapping Mr. Heineken
# 3     80057969  Movie                                     Love
# 4     80060297  Movie                        Manhattan Romance
# ...        ...    ...                                      ...
# 1794  80115101  Movie                                   Deuces
# 1795  80081955  Movie                     Five Nights in Maine
# 1796  70302835  Movie                                    Killa
# 1797  80125512  Movie                                 Lavender
# 1798  80085438  Movie                          Frank and Cindy
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1            Henrik Ruben Genz
# 2             Daniel Alfredson
# 3                   Gaspar Noé
# 4                  Tom O'Brien
# ...                        ...
# 1794                Jamal Hill
# 1795              Maris Curran
# 1796              Avinash Arun
# 1797          Ed Gass-Donnelly
# 1798          G.J. Echternkamp
#
#                                                    cast  \
# 0     Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1     James Franco, Kate Hudson, Tom Wilkinson, Omar...
# 2     Jim Sturgess, Sam Worthington, Ryan Kwanten, A...
# 3     Karl Glusman, Klara Kristin, Aomi Muyock, Ugo ...
# 4     Tom O'Brien, Katherine Waterston, Caitlin Fitz...
# ...                                                 ...
# 1794  Larenz Tate, Meagan Good, Lance Gross, Antoniq...
# 1795  David Oyelowo, Dianne Wiest, Rosie Perez, Teyo...
# 1796  Amruta Subhash, Archit Deodhar, Parth Bhalerao...
# 1797  Abbie Cornish, Diego Klattenhoff, Justin Long,...
# 1798                                                NaN
#
#                                             country_net         date_added  \
# 0              United States, India, South Korea, China  September 9, 2019
# 1        United States, United Kingdom, Denmark, Sweden  September 8, 2017
# 2     Netherlands, Belgium, United Kingdom, United S...  September 8, 2017
# 3                                       France, Belgium  September 8, 2017
# 4                                         United States  September 8, 2017
# ...                                                 ...                ...
# 1794                                      United States      April 1, 2017
# 1795                                      United States      April 1, 2017
# 1796                                              India      April 1, 2017
# 1797                              Canada, United States      April 1, 2017
# 1798                                      United States      April 1, 2016
#
#       release_year rating duration_net  ...  \
# 0             2019  TV-PG       90 min  ...
# 1             2014      R       90 min  ...
# 2             2015      R       95 min  ...
# 3             2015     NR      135 min  ...
# 4             2014  TV-14       98 min  ...
# ...            ...    ...          ...  ...
# 1794          2016  TV-MA       88 min  ...
# 1795          2015  TV-14       83 min  ...
# 1796          2014  TV-14      107 min  ...
# 1797          2016     NR       93 min  ...
# 1798          2007  TV-MA       70 min  ...
#
#                                                  actors  \
# 0     Jennifer Cameron, Brian Dobson, Michael Dobson...
# 1     Sam Spruell, Michael Fox, Diarmaid Murtagh, Fr...
# 2     Jim Sturgess, Sam Worthington, Ryan Kwanten, A...
# 3     Aomi Muyock, Karl Glusman, Klara Kristin, Ugo ...
# 4     Arnold C. Baker II, Jessie Barr, Tommy Burke, ...
# ...                                                 ...
# 1794  Larenz Tate, Meagan Good, Rotimi, Rick Gonzale...
# 1795  David Oyelowo, Hani Furstenberg, Neal Lerner, ...
# 1796  Amruta Subhash, Archit Deodhar, Parth Bhalerao...
# 1797  Abbie Cornish, Dermot Mulroney, Justin Long, L...
# 1798  Rene Russo, Oliver Platt, Johnny Simmons, Jane...
#
#                                        description_imdb avg_vote  votes  \
# 0     An ancient Chinese artifact has been stolen by...      3.2    185
# 1     Discovering a stash of cash in their dead tena...      5.5  14655
# 2     The inside story of the planning, execution, r...      6.1  18168
# 3     Murphy is an American living in Paris who ente...      6.1  39385
# 4     Danny, a commercial editor and documentary fil...      5.5   1082
# ...                                                 ...      ...    ...
# 1794  An undercover agent infiltrates a crime ring r...      5.9    790
# 1795  A young African American man, reeling from the...      4.5    617
# 1796  A 11-year-old Indian boy who has just lost his...      8.0   1170
# 1797  After discovering old fractures in her skull, ...      5.3   5083
# 1798  G.J. Echternkamp tells the story of his relati...      6.1    593
#
#          budget usa_gross_income worlwide_gross_income  metascore  \
# 0           NaN              NaN              $ 638351        NaN
# 1           NaN              NaN             $ 1857574       42.0
# 2           NaN              NaN             $ 3184017       33.0
# 3     $ 3000000         $ 249083              $ 861057       51.0
# 4           NaN              NaN                   NaN        NaN
# ...         ...              ...                   ...        ...
# 1794  $ 3000000              NaN                   NaN        NaN
# 1795        NaN          $ 15587               $ 15587       45.0
# 1796        NaN              NaN                   NaN        NaN
# 1797        NaN              NaN                   NaN       46.0
# 1798        NaN              NaN                   NaN        NaN
#
#      reviews_from_users reviews_from_critics
# 0                  11.0                  4.0
# 1                  48.0                 57.0
# 2                  37.0                 94.0
# 3                 106.0                198.0
# 4                   9.0                  5.0
# ...                 ...                  ...
# 1794                9.0                  NaN
# 1795               10.0                 14.0
# 1796               12.0                 14.0
# 1797               54.0                 24.0
# 1798                4.0                  3.0
#
# [1785 rows x 32 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-e373fa79cbf5> in <module>
# ----> 1 combined_movie_df.to_dataFrame
#
# ~/Applications/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to_dataFrame'

# %%
#There are very few tv shows with matching data
combined_TV_df = pd.merge(netflix_TV_df, imdb_df, left_on=['title'], 
                    right_on=['title'], suffixes=('_net', '_imdb') )

print (f" There are {len(combined_TV_df)} matching TV shows that have director data")
# Out:
#  There are 409 Tv shows that have director data

# %%
combined_movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1785 entries, 0 to 1798
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   show_id                1785 non-null   int64
#  1   type                   1785 non-null   object
#  2   title                  1785 non-null   object
#  3   director               1785 non-null   object
#  4   cast                   1783 non-null   object
#  5   country_net            1781 non-null   object
#  6   date_added             1785 non-null   object
#  7   release_year           1785 non-null   int64
#  8   rating                 1784 non-null   object
#  9   duration_net           1785 non-null   object
#  10  listed_in              1785 non-null   object
#  11  description_net        1785 non-null   object
#  12  imdb_title_id          1785 non-null   object
#  13  original_title         1785 non-null   object
#  14  year                   1785 non-null   int64
#  15  date_published         1785 non-null   object
#  16  genre                  1785 non-null   object
#  17  duration_imdb          1785 non-null   int64
#  18  country_imdb           1784 non-null   object
#  19  language               1771 non-null   object
#  20  writer                 1760 non-null   object
#  21  production_company     1738 non-null   object
#  22  actors                 1785 non-null   object
#  23  description_imdb       1785 non-null   object
#  24  avg_vote               1785 non-null   float64
#  25  votes                  1785 non-null   int64
#  26  budget                 738 non-null    object
#  27  usa_gross_income       765 non-null    object
#  28  worlwide_gross_income  1137 non-null   object
#  29  metascore              868 non-null    float64
#  30  reviews_from_users     1766 non-null   float64
#  31  reviews_from_critics   1694 non-null   float64
# dtypes: float64(4), int64(5), object(23)
# memory usage: 460.2+ KB

# %%
#based on Ahmad's advice we can cut the columns that are missing a lot of information
#27 budget # 28 usa_gross_income #29 worlwide_gross_income #30 object metascore             
combined_movie_df = combined_movie_df[['show_id', 'type', 'title',
    'cast', 'country_net', 'date_added', 'release_year', 'rating', 'duration_net',
'listed_in', 'description_net', 'imdb_title_id', 'original_title', 'year',
'date_published', 'genre', 'duration_imdb', 'country_imdb', 'language',
'writer', 'production_company', 'actors', 'description_imdb', 'avg_vote',
'votes']].copy()
combined_movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1785 entries, 0 to 1798
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   show_id             1785 non-null   int64
#  1   type                1785 non-null   object
#  2   title               1785 non-null   object
#  3   cast                1783 non-null   object
#  4   country_net         1781 non-null   object
#  5   date_added          1785 non-null   object
#  6   release_year        1785 non-null   int64
#  7   rating              1784 non-null   object
#  8   duration_net        1785 non-null   object
#  9   listed_in           1785 non-null   object
#  10  description_net     1785 non-null   object
#  11  imdb_title_id       1785 non-null   object
#  12  original_title      1785 non-null   object
#  13  year                1785 non-null   int64
#  14  date_published      1785 non-null   object
#  15  genre               1785 non-null   object
#  16  duration_imdb       1785 non-null   int64
#  17  country_imdb        1784 non-null   object
#  18  language            1771 non-null   object
#  19  writer              1760 non-null   object
#  20  production_company  1738 non-null   object
#  21  actors              1785 non-null   object
#  22  description_imdb    1785 non-null   object
#  23  avg_vote            1785 non-null   float64
#  24  votes               1785 non-null   int64
# dtypes: float64(1), int64(5), object(19)
# memory usage: 362.6+ KB

# %%
# From here our problems are:
# Should we cut some more coumns?
# There are some duplicated columns  (cast/actors, country, release year/year, duration, description)
# There is some missing data(most of these can be fixed by combiining data from the duplicated columns)
# there are some incorrect data types (release year/year, duration_net)

# %%
# to find null values
bool_series = pd.isnull(combined_movie_df["rating"])  
combined_movie_df[bool_series].T
# Out:
#                                                                   782
# show_id                                                      80144119
# type                                                            Movie
# title                                            My Honor Was Loyalty
# cast                Leone Frisa, Paolo Vaccarino, Francesco Miglio...
# country_net                                                     Italy
# date_added                                              March 1, 2017
# release_year                                                     2015
# rating                                                            NaN
# duration_net                                                  115 min
# listed_in                                                      Dramas
# description_net     Amid the chaos and horror of World War II, a c...
# imdb_title_id                                               tt4544696
# original_title                                   My Honor Was Loyalty
# year                                                             2016
# date_published                                             2017-03-01
# genre                                                      Drama, War
# duration_imdb                                                      95
# country_imdb                                                    Italy
# language                                              German, English
# writer                                                Alessandro Pepe
# production_company                                                NaN
# actors              Leone Frisa, Francesco Migliore, Paolo Vaccari...
# description_imdb    Untersharführer Ludwig Herckel (Leone Frisa), ...
# avg_vote                                                          4.4
# votes                                                             893

# %%
# if we need to find additional data we can use this package
# pip install imdbpy

# %%
# This is the code we used in class for cleaning data and exporting it

# %% [markdown]
# ### Transform premise DataFrame

# %%
new_premise_df = premise_df[['Premises Name', 'County ID Code']].copy()
new_premise_df.head()

# %%
new_premise_df.rename(columns = {'Premises Name':'premise_name'}, inplace = True)

# %%
new_premise_df.rename(columns = {'County ID Code':'county_id'}, inplace = True) 
new_premise_df.duplicated()
new_premise_df.drop_duplicates(['premise_name'])

# %% [markdown]
# ### Transform county DataFrame

# %%
county_df.head()
new_county_df = county_df[['County Name (Licensee)', 'County ID Code', 'License Count']].copy()
new_county_df.count()

# %%
new_county_df.rename(columns = {'License Count':'license_count',
                               "County Name (Licensee)": "county_name",
                               "County ID Code": "county_id"}, inplace = True) 

# A `county` table that contains the columns `id`, `county_name`, 
#     `license_count` and `county_id`.
new_county_df

# %% [markdown]
# ### Create database connection

# %%
rds_connection_string = "postgres:1117@localhost:5432/customer_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Confirm tables
engine.table_names()

# %% [markdown]
# ### Load DataFrames into database

# %%
new_county_df.to_sql(name='county', con=engine, if_exists='append', index=False)

# %%
new_premise_df.to_sql(name='premise', con=engine, if_exists='append', index=False)
