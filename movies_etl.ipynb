# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
imdb_file = "IMDb movies.csv"
imdb_df = pd.read_csv(imdb_file)
imdb_df.head()
# Out:
#   imdb_title_id                                              title  \
# 0     tt0000574                        The Story of the Kelly Gang
# 1     tt0001892                                     Den sorte drøm
# 2     tt0002101                                          Cleopatra
# 3     tt0002130                                          L'Inferno
# 4     tt0002199  From the Manger to the Cross; or, Jesus of Naz...
#
#                                       original_title  year date_published  \
# 0                        The Story of the Kelly Gang  1906     1906-12-26
# 1                                     Den sorte drøm  1911     1911-08-19
# 2                                          Cleopatra  1912     1912-11-13
# 3                                          L'Inferno  1911     1911-03-06
# 4  From the Manger to the Cross; or, Jesus of Naz...  1912           1913
#
#                        genre  duration           country language  \
# 0    Biography, Crime, Drama        70         Australia      NaN
# 1                      Drama        53  Germany, Denmark      NaN
# 2             Drama, History       100               USA  English
# 3  Adventure, Drama, Fantasy        68             Italy  Italian
# 4           Biography, Drama        60               USA  English
#
#                               director  ...  \
# 0                         Charles Tait  ...
# 1                            Urban Gad  ...
# 2                   Charles L. Gaskill  ...
# 3  Francesco Bertolini, Adolfo Padovan  ...
# 4                        Sidney Olcott  ...
#
#                                               actors  \
# 0  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 1  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 2  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 3  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
# 4  R. Henderson Bland, Percy Dyer, Gene Gauntier,...
#
#                                          description avg_vote votes   budget  \
# 0  True story of notorious Australian outlaw Ned ...      6.1   537   $ 2250
# 1  Two men of high rank are both wooing the beaut...      5.9   171      NaN
# 2  The fabled queen of Egypt's affair with Roman ...      5.2   420  $ 45000
# 3  Loosely adapted from Dante's Divine Comedy and...      7.0  2019      NaN
# 4  An account of the life of Jesus Christ, based ...      5.7   438      NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                7.0
# 1               NaN                   NaN       NaN                4.0
# 2               NaN                   NaN       NaN               24.0
# 3               NaN                   NaN       NaN               28.0
# 4               NaN                   NaN       NaN               12.0
#
#    reviews_from_critics
# 0                   7.0
# 1                   2.0
# 2                   3.0
# 3                  14.0
# 4                   5.0
#
# [5 rows x 22 columns]

# %%
netflix_file = "netflix_titles.csv"
netflix_df = pd.read_csv(netflix_file)
netflix_df.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 1                            United Kingdom  September 9, 2016          2016
# 2                             United States  September 8, 2018          2013
# 3                             United States  September 8, 2018          2016
# 4                             United States  September 8, 2017          2017
#
#      rating  duration                           listed_in  \
# 0     TV-PG    90 min  Children & Family Movies, Comedies
# 1     TV-MA    94 min                     Stand-Up Comedy
# 2  TV-Y7-FV  1 Season                            Kids' TV
# 3     TV-Y7  1 Season                            Kids' TV
# 4     TV-14    99 min                            Comedies
#
#                                          description
# 0  Before planning an awesome wedding for his gra...
# 1  Jandino Asporaat riffs on the challenges of ra...
# 2  With the help of three human allies, the Autob...
# 3  When a prison ship crash unleashes hundreds of...
# 4  When nerdy high schooler Dani finally attracts...

# %%
netflix_df.drop_duplicates()
netflix_df["type"].value_counts()
# Out:
# Movie      4265
# TV Show    1969
# Name: type, dtype: int64

# %%
netflix_df["title"].value_counts()
netflix_df["title"]=="Love"
# Out:
# Love                                                  3
# Oh My Ghost                                           3
# Tunnel                                                3
# The Silence                                           3
# Limitless                                             3
#                                                      ..
# Krish Trish and Baltiboy: Oversmartness Never Pays    1
# Tremors 5:  Bloodline                                 1
# OCTB                                                  1
# The Andy Griffith Show                                1
# Family Blood                                          1
# Name: title, Length: 6172, dtype: int64

# %%
# merge on title cuts the netflix data base from 6234 to 3040
# there are no duplicates
large_df = pd.merge(netflix_df, imdb_df, left_on='title', right_on='title')

# %%
large_df.head()
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  70304990  Movie                              Good People
# 2  70299204  Movie                  Kidnapping Mr. Heineken
# 3  80057969  Movie                                     Love
# 4  80057969  Movie                                     Love
#
#                  director_x  \
# 0  Richard Finn, Tim Maltby
# 1         Henrik Ruben Genz
# 2          Daniel Alfredson
# 3                Gaspar Noé
# 4                Gaspar Noé
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1  James Franco, Kate Hudson, Tom Wilkinson, Omar...
# 2  Jim Sturgess, Sam Worthington, Ryan Kwanten, A...
# 3  Karl Glusman, Klara Kristin, Aomi Muyock, Ugo ...
# 4  Karl Glusman, Klara Kristin, Aomi Muyock, Ugo ...
#
#                                            country_x         date_added  \
# 0           United States, India, South Korea, China  September 9, 2019
# 1     United States, United Kingdom, Denmark, Sweden  September 8, 2017
# 2  Netherlands, Belgium, United Kingdom, United S...  September 8, 2017
# 3                                    France, Belgium  September 8, 2017
# 4                                    France, Belgium  September 8, 2017
#
#    release_year rating duration_x  ...  \
# 0          2019  TV-PG     90 min  ...
# 1          2014      R     90 min  ...
# 2          2015      R     95 min  ...
# 3          2015     NR    135 min  ...
# 4          2015     NR    135 min  ...
#
#                                               actors  \
# 0  Jennifer Cameron, Brian Dobson, Michael Dobson...
# 1  Sam Spruell, Michael Fox, Diarmaid Murtagh, Fr...
# 2  Jim Sturgess, Sam Worthington, Ryan Kwanten, A...
# 3  John Gilbert, Greta Garbo, George Fawcett, Emi...
# 4  Salman Khan, Rita Bhaduri, Shafi Inamdar, Amja...
#
#                                        description_y avg_vote  votes  \
# 0  An ancient Chinese artifact has been stolen by...      3.2    185
# 1  Discovering a stash of cash in their dead tena...      5.5  14655
# 2  The inside story of the planning, execution, r...      6.1  18168
# 3  A married woman compromises her social standin...      7.0    860
# 4  Prithvi and Maggie fall in love and decide to ...      5.9    932
#
#      budget usa_gross_income worlwide_gross_income  metascore  \
# 0       NaN              NaN              $ 638351        NaN
# 1       NaN              NaN             $ 1857574       42.0
# 2       NaN              NaN             $ 3184017       33.0
# 3  $ 488000              NaN                   NaN        NaN
# 4       NaN              NaN                   NaN        NaN
#
#   reviews_from_users reviews_from_critics
# 0               11.0                  4.0
# 1               48.0                 57.0
# 2               37.0                 94.0
# 3               14.0                  9.0
# 4                4.0                  NaN
#
# [5 rows x 33 columns]

# %%
large_df.drop_duplicates()
short_df = large_df[["show_id","title","imdb_title_id"]]
short_df
# Out:
#        show_id                                    title imdb_title_id
# 0     81145628  Norm of the North: King Sized Adventure     tt9428190
# 1     70304990                              Good People     tt1361318
# 2     70299204                  Kidnapping Mr. Heineken     tt2917388
# 3     80057969                                     Love     tt0018107
# 4     80057969                                     Love     tt0392360
# ...        ...                                      ...           ...
# 3035  70272742                              Justin Time     tt1251735
# 3036  70136122                                    Weeds     tt0094304
# 3037  70153404                                  Friends     tt0067118
# 3038  70153404                                  Friends     tt0255178
# 3039  70153404                                  Friends     tt0308280
#
# [3040 rows x 3 columns]

# %%
# Out:
# Collecting imdbpy
#   Downloading IMDbPY-6.8-py3-none-any.whl (295 kB)
#      |████████████████████████████████| 295 kB 1.9 MB/s eta 0:00:01
# Requirement already satisfied: lxml in /Users/imacmattimacmatt/Applications/anaconda3/lib/python3.7/site-packages (from imdbpy) (4.5.0)
# Requirement already satisfied: SQLAlchemy in /Users/imacmattimacmatt/Applications/anaconda3/lib/python3.7/site-packages (from imdbpy) (1.3.13)
# Installing collected packages: imdbpy
# Successfully installed imdbpy-6.8

# %%
# Out:
# Directors:
# Lana Wachowski
# Lilly Wachowski
# Genres:
# Action
# Sci-Fi
# 0000154 Mel Gibson
# 2153167 Mel Gibson
# 0317112 Mel Gibson
# 2800055 Mel Gibson
# 3323885 Adam Taylor
# 3742421 Melina Mari Bryant   nickname
# 0316945 Donal Gibson
# 0317195 Terel Gibson
# 0316878 Cal Gibson
# 2106809 Raquel Gibson
# 3912400 Jamel Gibson
# 0316950 E.L. Gibson
# 4047961 Noel Gibson
# 6928816 Christel Gibson
# 2798174 Daniel Gibson
# 5480601 Rachel Gibson
# 1270944 Paul Gibson
# 3894412 Paul Gibson
# 7454542 L. Gibson
# 2988370 Mal Gibson

# %%
# Out:
# The Matrix

# %% [markdown]
# ### Transform premise DataFrame

# %%
new_premise_df = premise_df[['Premises Name', 'County ID Code']].copy()
new_premise_df.head()
# Out:
#                   Premises Name  County ID Code
# 0  CANA ARRIBA GROCERY NO 2 INC               0
# 1    JOHANA GROCERY & DELI CORP               0
# 2             TKO BEVERAGES LLC               1
# 3             TKO BEVERAGES LLC               1
# 4  181 LEXINGTON AVENUE BBQ LLC               2

# %%
new_premise_df.rename(columns = {'Premises Name':'premise_name'}, inplace = True)

# %%
new_premise_df.rename(columns = {'County ID Code':'county_id'}, inplace = True) 
new_premise_df.duplicated()
new_premise_df.drop_duplicates(['premise_name'])
# Out:
#                       premise_name  county_id
# 0     CANA ARRIBA GROCERY NO 2 INC          0
# 1       JOHANA GROCERY & DELI CORP          0
# 2                TKO BEVERAGES LLC          1
# 4     181 LEXINGTON AVENUE BBQ LLC          2
# 5           AZIZ DELI & GRILL CORP          1
# ...                            ...        ...
# 1858     H CITY DISCOUNT STORE INC         14
# 1859              YONY P DELI CORP         14
# 1860              JOSEPH SCHLEIMER         12
# 1861               DAIRY SHACK LLC         10
# 1862         TARTINERY LIBERTY LLC          2
#
# [1664 rows x 2 columns]

# %% [markdown]
# ### Transform county DataFrame

# %%
county_df.head()
new_county_df = county_df[['County Name (Licensee)', 'County ID Code', 'License Count']].copy()
new_county_df.count()
# Out:
# County Name (Licensee)    62
# County ID Code            62
# License Count             62
# dtype: int64

# %%
new_county_df.rename(columns = {'License Count':'license_count',
                               "County Name (Licensee)": "county_name",
                               "County ID Code": "county_id"}, inplace = True) 

# A `county` table that contains the columns `id`, `county_name`, 
#     `license_count` and `county_id`.
new_county_df
# Out:
#     county_name  county_id  license_count
# 0        ALBANY          5             77
# 1      ALLEGANY         59              4
# 2         BRONX          0            104
# 3        BROOME         35             14
# 4   CATTARAUGUS         41              9
# ..          ...        ...            ...
# 57   WASHINGTON         15              5
# 58        WAYNE         52              9
# 59  WESTCHESTER         20             73
# 60      WYOMING         56              2
# 61        YATES         22              1
#
# [62 rows x 3 columns]

# %% [markdown]
# ### Create database connection

# %%
rds_connection_string = "postgres:1117@localhost:5432/customer_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['premise', 'county']

# %% [markdown]
# ### Load DataFrames into database

# %%
new_county_df.to_sql(name='county', con=engine, if_exists='append', index=False)

# %%
new_premise_df.to_sql(name='premise', con=engine, if_exists='append', index=False)
